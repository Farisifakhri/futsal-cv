# %%
import torch
import numpy as np

# 1. FIX: Bypass PyTorch 2.6+ UnpicklingError
_original_torch_load = torch.load
def _patched_torch_load(*args, **kwargs):
    kwargs.setdefault('weights_only', False)
    return _original_torch_load(*args, **kwargs)
torch.load = _patched_torch_load

# 2. FIX: Kompatibilitas numpy 2.0+ trapz
if not hasattr(np, 'trapz'):
    np.trapz = np.trapezoid

from ultralytics import YOLO

# 3. Load model terbaik hasil training
model = YOLO("models/best_futsal_yolov8n.pt")

# 4. Jalankan Evaluasi Murni pada data TEST
metrics = model.val(data="data_augmented/data.yaml", split="test")

# 5. Tampilkan Hasil mAP Data Test
print("\n" + "=" * 50)
print(f"Overall mAP50 (Data Test)     : {metrics.box.map50:.3f}")
print(f"Overall mAP50-95 (Data Test)  : {metrics.box.map:.3f}")
print("=" * 50)
# Out:
# WARNING ⚠️ models/best_futsal_yolov8n.pt appears to require 'dill', which is not in ultralytics requirements.
# AutoInstall will run now for 'dill' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official YOLOv8 model, i.e. 'yolo predict model=yolov8n.pt'
# requirements: Ultralytics requirement ['dill'] not found, attempting AutoUpdate...
# Collecting dill
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
# Installing collected packages: dill
# Successfully installed dill-0.4.1
#
# requirements: AutoUpdate success ✅ 4.3s, installed 1 package: ['dill']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Ultralytics YOLOv8.1.0 🚀 Python-3.12.13 torch-2.13.0+cu130 CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# Model summary (fused): 168 layers, 3006428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /mnt/d_drive/linuxstorage/Coding/DL/uas_comvis/futsal-cv/data_augmented/test/labels... 36 images, 0 backgrounds, 0 corrupt: 100%|██████████| 36/36 [00:00<00:00, 465.40it/s]
# val: New cache created: /mnt/d_drive/linuxstorage/Coding/DL/uas_comvis/futsal-cv/data_augmented/test/labels.cache
# /mnt/d_drive/linuxstorage/Coding/DL/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:759: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:05<00:00,  1.78s/it]
#                    all         36        404      0.806      0.693      0.743      0.561
#                   ball         36         26      0.741      0.331      0.466      0.303
#             goalkeeper         36         24      0.739      0.792      0.779      0.521
#                 player         36        259        0.9      0.807      0.855      0.711
#                referee         36         95      0.844      0.842      0.872      0.708
# Speed: 2.8ms preprocess, 117.2ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs/detect/val
#
# ==================================================
# 📊 Overall mAP50 (Data Test)     : 0.743
# 📊 Overall mAP50-95 (Data Test)  : 0.561
# ==================================================

# %%
import torch
import numpy as np

# 1. FIX: Bypass PyTorch 2.6+ UnpicklingError
_original_torch_load = torch.load
def _patched_torch_load(*args, **kwargs):
    kwargs.setdefault('weights_only', False)
    return _original_torch_load(*args, **kwargs)
torch.load = _patched_torch_load

# 2. FIX: Kompatibilitas numpy 2.0+ trapz
if not hasattr(np, 'trapz'):
    np.trapz = np.trapezoid

from ultralytics import YOLO

# 3. Load model terbaik hasil training
model = YOLO("models/best_futsal_yolov8m.pt")

# 4. Jalankan Evaluasi Murni pada data TEST
metrics = model.val(data="data_augmented/data.yaml", split="test")

# 5. Tampilkan Hasil mAP Data Test
print("\n" + "=" * 50)
print(f"📊 Overall mAP50 (Data Test)     : {metrics.box.map50:.3f}")
print(f"📊 Overall mAP50-95 (Data Test)  : {metrics.box.map:.3f}")
print("=" * 50)
# Out:
# Ultralytics YOLOv8.1.0 🚀 Python-3.12.13 torch-2.13.0+cu130 CPU (AMD Ryzen 5 5600H with Radeon Graphics)
# Model summary (fused): 218 layers, 25842076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /mnt/d_drive/linuxstorage/Coding/DL/uas_comvis/futsal-cv/data_augmented/test/labels.cache... 36 images, 0 backgrounds, 0 corrupt: 100%|██████████| 36/36 [00:00<?, ?it/s]
# /mnt/d_drive/linuxstorage/Coding/DL/.venv/lib/python3.12/site-packages/torch/utils/data/dataloader.py:759: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:42<00:00, 14.32s/it]
#                    all         36        404      0.872      0.739        0.8      0.619
#                   ball         36         26      0.874      0.533      0.646      0.468
#             goalkeeper         36         24      0.778      0.833      0.884       0.66
#                 player         36        259       0.94       0.78      0.826      0.678
#                referee         36         95      0.895       0.81      0.846      0.668
# Speed: 7.7ms preprocess, 1133.6ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val2
#
# ==================================================
# 📊 Overall mAP50 (Data Test)     : 0.800
# 📊 Overall mAP50-95 (Data Test)  : 0.619
# ==================================================
